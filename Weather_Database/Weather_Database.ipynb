# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b9a601cdf6b4126931391762db06a57

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + ""
city_weather = requests.get(city_url)
city_weather
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b9a601cdf6b4126931391762db06a57&q=

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
cities
# Out:
# ['busselton',
#  'hilo',
#  'albany',
#  'carnarvon',
#  'karlskrona',
#  'pochutla',
#  'roald',
#  'fortuna',
#  'yashiro',
#  'amderma',
#  'tsihombe',
#  'cape town',
#  'axim',
#  'umzimvubu',
#  'gobabis',
#  'kumluca',
#  'grand-santi',
#  'bur gabo',
#  'illoqqortoormiut',
#  'chokurdakh',
#  'jamestown',
#  'dikson',
#  'marcona',
#  'rikitea',
#  'ancud',
#  'norman wells',
#  'aksu',
#  'port alfred',
#  'bredasdorp',
#  'tommot',
#  'cidreira',
#  'zeya',
#  'punta arenas',
#  'saint-philippe',
#  'savannah bight',
#  'ushuaia',
#  'nikolskoye',
#  'sakakah',
#  'lashio',
#  'lebu',
#  'yellowknife',
#  'loandjili',
#  'mildura',
#  'saint-augustin',
#  'airai',
#  'cherskiy',
#  'salalah',
#  'tiksi',
#  'kapaa',
#  'kodiak',
#  'east london',
#  'cabo san lucas',
#  'sistranda',
#  'hamilton',
#  'harper',
#  'fare',
#  'labytnangi',
#  'lykhivka',
#  'galiwinku',
#  'castro',
#  'chagda',
#  'bereda',
#  'addi ugri',
#  'kuche',
#  'nanortalik',
#  'manacapuru',
#  'hobart',
#  'esperance',
#  'kaohsiung',
#  'kavaratti',
#  'avarua',
#  'vardo',
#  'hithadhoo',
#  'barrow',
#  'nizhneyansk',
#  'hasaki',
#  'new waterford',
#  'bengkulu',
#  'price',
#  'dalvik',
#  'rybnaya sloboda',
#  'helena',
#  'ahipara',
#  'tuktoyaktuk',
#  'mokhsogollokh',
#  'anloga',
#  'perth',
#  'mataura',
#  'lodja',
#  'chuy',
#  'kavieng',
#  'arraial do cabo',
#  'buzdyak',
#  'hirara',
#  'srednekolymsk',
#  'sechura',
#  'vilhena',
#  'karachi',
#  'chapais',
#  'hermanus',
#  'lavrentiya',
#  'tasiilaq',
#  'puerto ayora',
#  'garowe',
#  'acari',
#  'lubaczow',
#  'umea',
#  'natal',
#  'kindu',
#  'hambantota',
#  'itoman',
#  'ilulissat',
#  'kudahuvadhoo',
#  'taolanaro',
#  'svecha',
#  'krabi',
#  'navalcarnero',
#  'doha',
#  'svetlogorsk',
#  'san ramon',
#  'burnie',
#  'cuamba',
#  'grand river south east',
#  'balikpapan',
#  'wattegama',
#  'jaru',
#  'nanaimo',
#  'noumea',
#  'saint george',
#  'santa isabel do rio negro',
#  'longyearbyen',
#  'vyazemskiy',
#  'nizhniy tagil',
#  'beloha',
#  'thompson',
#  'dauphin',
#  'bethel',
#  'khatanga',
#  'ribeira grande',
#  'georgetown',
#  'tuatapere',
#  'gidam',
#  'coria',
#  'fatehpur',
#  'asbestos',
#  'severo-kurilsk',
#  'tessalit',
#  'atuona',
#  'port lincoln',
#  'butaritari',
#  'ouallam',
#  'suzun',
#  'vostok',
#  'kanniyakumari',
#  'buraydah',
#  'belushya guba',
#  'isla mujeres',
#  'moose factory',
#  'cayenne',
#  'itarema',
#  'ust-uda',
#  'shenkursk',
#  'broome',
#  'namibe',
#  'ekuvukeni',
#  'seoul',
#  'wajima',
#  'tarakan',
#  'marawi',
#  'bukachacha',
#  'pangnirtung',
#  'port elizabeth',
#  'upernavik',
#  'linxia',
#  'samagaltay',
#  'taneatua',
#  'college',
#  'san andres',
#  'naze',
#  'sao filipe',
#  'fraga',
#  'constitucion',
#  'gamba',
#  'victoria',
#  'poum',
#  'salinopolis',
#  'zirgan',
#  'pevek',
#  'baker city',
#  'pampa',
#  'bambous virieux',
#  'gat',
#  'ponerihouen',
#  'torbay',
#  'geraldton',
#  'yar-sale',
#  'shache',
#  'boyolangu',
#  'teya',
#  'souillac',
#  'mar del plata',
#  'qaanaaq',
#  'alyangula',
#  'tumannyy',
#  'maragogi',
#  'maumere',
#  'jiangyou',
#  'karkaralinsk',
#  'mys shmidta',
#  'norsup',
#  'coos bay',
#  'tanjung morawa',
#  'dwarka',
#  'stabat',
#  'varena',
#  'asau',
#  'ereymentau',
#  'beringovskiy',
#  'thinadhoo',
#  'olafsvik',
#  'sorong',
#  'lompoc',
#  'khao yoi',
#  'ponta do sol',
#  'korla',
#  'ottawa',
#  'amarante do maranhao',
#  'lorengau',
#  'saskylakh',
#  'vila velha',
#  'abu kamal',
#  'san quintin',
#  'vaini',
#  'bluff',
#  'dunedin',
#  'saint-pierre',
#  'luderitz',
#  'hue',
#  'pagudpud',
#  'pisco',
#  'mumford',
#  'gijon',
#  'vestmannaeyjar',
#  'flinders',
#  'wahran',
#  'qovlar',
#  'lake city',
#  'avera',
#  'auki',
#  'camopi',
#  'lake charles',
#  'yakeshi',
#  'sentyabrskiy',
#  'diego de almagro',
#  'zabaykalsk',
#  'loikaw',
#  'puerto narino',
#  'scottsbluff',
#  'ambodifototra',
#  'kachikau',
#  'tacoronte',
#  'kimbe',
#  'fairfield',
#  'sindor',
#  'alta floresta',
#  'nome',
#  'sitka',
#  'zhongxing',
#  'berlevag',
#  'tyup',
#  'christchurch',
#  'yaransk',
#  'kaitangata',
#  'ahuimanu',
#  'new norfolk',
#  'san angelo',
#  'komsomolskiy',
#  'bagepalli',
#  'brigantine',
#  'cockburn town',
#  'taoudenni',
#  'krasnyy chikoy',
#  'londrina',
#  'saldanha',
#  'samarai',
#  'mehamn',
#  'vetluga',
#  'selikhino',
#  'kurilsk',
#  'kahului',
#  'panguipulli',
#  'udachnyy',
#  'erenhot',
#  'olga',
#  'champerico',
#  'lagoa',
#  'leningradskiy',
#  'rylsk',
#  'oktyabrskoye',
#  'attawapiskat',
#  'dmanisi',
#  'mursalimkino',
#  'tura',
#  'roebourne',
#  'bolungarvik',
#  'uvira',
#  'bonthe',
#  'hofn',
#  'ginir',
#  'bathsheba',
#  'itororo',
#  'barabai',
#  'ossora',
#  'qaqortoq',
#  'namie',
#  'xai-xai',
#  'hopewell',
#  'dolbeau',
#  'presidencia roque saenz pena',
#  'aksarayskiy',
#  'ulaangom',
#  'tucupita',
#  'erdaojiang',
#  'klaksvik',
#  'manokwari',
#  'camacha',
#  'endicott',
#  'iqaluit',
#  'yulara',
#  'la ronge',
#  'zinder',
#  'north bend',
#  'sassandra',
#  'akyab',
#  'sinjar',
#  'kadnikov',
#  'carutapera',
#  'zhigansk',
#  'bonnyville',
#  'qasigiannguit',
#  'miandrivazo',
#  'deputatskiy',
#  'reims',
#  'samusu',
#  'miri',
#  'san cristobal',
#  'praia',
#  'caravelas',
#  'marsa matruh',
#  'juneau',
#  'port hardy',
#  'phangnga',
#  'hervey bay',
#  'half moon bay',
#  'ranir bazar',
#  'iquitos',
#  'mikuni',
#  'terrace bay',
#  'saleaula',
#  'cap-aux-meules',
#  'naryan-mar',
#  'dakar',
#  'omsukchan',
#  'tautira',
#  'konya',
#  'barentsburg',
#  'ayan',
#  'namatanai',
#  'aykhal',
#  'laguna',
#  'polson',
#  'gizo',
#  'acapulco',
#  'edson',
#  'sobolevo',
#  'meiganga',
#  'provideniya',
#  'martapura',
#  'puertollano',
#  'los corrales de buelna',
#  'monatele',
#  'karaul',
#  'moerai',
#  'riyadh',
#  'balod',
#  'grand centre',
#  'padampur',
#  'louis trichardt',
#  'xucheng',
#  'ola',
#  'umm kaddadah',
#  'paciran',
#  'livramento',
#  'belokurikha',
#  'beruwala',
#  'pousat',
#  'kaiyuan',
#  'talnakh',
#  'kruisfontein',
#  'vaitupu',
#  'south lyon',
#  'bideford',
#  'astana',
#  'mitchell',
#  'foca',
#  'te anau',
#  'westport',
#  'masindi',
#  'sibolga',
#  'sinnamary',
#  'seymchan',
#  'guerrero negro',
#  'raub',
#  'tiznit',
#  'solsvik',
#  'balclutha',
#  'san diego',
#  'shagonar',
#  'hammerfest',
#  'coquimbo',
#  'oakdale',
#  'abha',
#  'bud',
#  'nguiu',
#  'labuhan',
#  'mount isa',
#  'mvuma',
#  'nikolayevsk-na-amure',
#  'clyde river',
#  'ampanihy',
#  'adrar',
#  'fernandez',
#  'logansport',
#  'aklavik',
#  'port macquarie',
#  'micomeseng',
#  'marsh harbour',
#  'amparai',
#  'bocas del toro',
#  'broken hill',
#  'goderich',
#  'saint-joseph',
#  'oruro',
#  'paradwip',
#  'misratah',
#  'vila franca do campo',
#  'kasongo',
#  'savinskiy',
#  'kalmunai',
#  'ambanja',
#  'karratha',
#  'halifax',
#  'kot putli',
#  'krasnogvardeyskoye',
#  'manicore',
#  'la tuque',
#  'slave lake',
#  'palmer',
#  'monterey',
#  'abu samrah',
#  'coahuayana',
#  'santa marta',
#  'jeremie',
#  'sakaiminato',
#  'ixtapa',
#  'kirovo-chepetsk',
#  'paamiut',
#  'whitecourt',
#  'madimba',
#  'surat',
#  'yatou',
#  'viedma',
#  'kenora',
#  'vyartsilya',
#  'lokosovo',
#  'grand gaube',
#  'oistins',
#  'kushmurun',
#  'hit',
#  'bac lieu',
#  'hastings',
#  'richards bay',
#  'belyy yar',
#  'kawana waters',
#  'sosnovo-ozerskoye',
#  'vanimo',
#  'kirakira',
#  'chernyshevskiy',
#  'barra do garcas',
#  'wilmington',
#  'omboue',
#  'disna',
#  'chastoozerye',
#  'aloleng',
#  'bugalagrande',
#  'brandon',
#  'anadyr',
#  'necochea',
#  'taunggyi',
#  'auriflama',
#  'mtsensk',
#  'katsuura',
#  'nizhnyaya tavda',
#  'boden',
#  'canakkale',
#  'grand forks',
#  'pindiga',
#  'tual',
#  'chico',
#  'portland',
#  'tilichiki',
#  'bafra',
#  'bako',
#  'chicama',
#  'antofagasta',
#  'alofi',
#  'atambua',
#  'tabiauea',
#  'evensk',
#  'puerto lopez',
#  'kadykchan',
#  'paita',
#  'balimo',
#  'altay',
#  'flin flon',
#  'bagdarin',
#  'matara',
#  'mareeba',
#  'margate',
#  'xuddur',
#  'charlottesville',
#  'mandan',
#  'bilma',
#  'atkinson',
#  'sisimiut',
#  'port blair',
#  'arlit',
#  'russell',
#  'inderborskiy',
#  'biloxi',
#  'bata',
#  'monster',
#  'shankargarh',
#  'ostrovnoy',
#  'mazagao',
#  'san blas',
#  'henties bay',
#  'sibu',
#  'changji',
#  'charters towers',
#  'omaruru',
#  'tecoanapa',
#  'kapoeta',
#  'lata',
#  'elizabeth city',
#  'pandan',
#  'hami',
#  'santa comba',
#  'mankono',
#  'sorland',
#  'temaraia',
#  'kathmandu',
#  'tuxpan',
#  'cururupu',
#  'wum',
#  'fatehgarh',
#  'high prairie',
#  'veraval',
#  'pemangkat',
#  'saurimo',
#  'bayangol',
#  'istok',
#  'tagusao',
#  'ada',
#  'japura',
#  'mopipi',
#  'mabaruma',
#  'nantucket',
#  'husavik',
#  'bloomfield',
#  'yaan',
#  'chaiya',
#  'trenggalek',
#  'uray',
#  'mahibadhoo',
#  'khandyga',
#  'lubao',
#  'mayumba',
#  'gurskoye',
#  'san patricio',
#  'yarim',
#  'eureka',
#  'halalo',
#  'vila do maio',
#  'huarmey',
#  'dzhusaly',
#  'borovskoy',
#  'san policarpo',
#  'oktyabrskiy',
#  'toliary',
#  'thoen',
#  'ngukurr',
#  'floro',
#  'mahina',
#  'rio gallegos',
#  'honningsvag',
#  'svetlaya',
#  'mariakani',
#  'palaikastron',
#  'mulege',
#  'bayan',
#  'coihaique',
#  'lufilufi',
#  'kitale',
#  'severo-yeniseyskiy',
#  'sawai madhopur',
#  'gilazi',
#  'basco',
#  'sola',
#  'beroroha',
#  'pecos',
#  'upington',
#  'oranjemund',
#  'alihe',
#  'marfino',
#  'bestobe',
#  'sarangani',
#  'la paz',
#  'artyk',
#  'ca mau',
#  'u thong',
#  'kununurra',
#  'galle',
#  'pizarro',
#  'nago',
#  'honiara',
#  'terra rica',
#  'akureyri',
#  'adelaide',
#  'bilibino',
#  'san ignacio',
#  'balkanabat',
#  'waitati',
#  'yverdon',
#  'mao',
#  'manubul',
#  'mount gambier',
#  'isangel',
#  'chardara',
#  'sijunjung',
#  'numan',
#  'conde',
#  'ladario',
#  'biak',
#  'plettenberg bay',
#  'boma',
#  'batemans bay',
#  'maridi',
#  'praia da vitoria',
#  'vandra',
#  'rabaul',
#  'kilindoni',
#  'fairbanks',
#  'baracoa',
#  'payyannur',
#  'atagay',
#  'haines junction',
#  'raudeberg',
#  'taltal',
#  'hunza',
#  'shetpe',
#  'bandarbeyla',
#  'kaseda',
#  'kholm-zhirkovskiy',
#  'aswan',
#  'nishihara',
#  'sept-iles',
#  'shimoda',
#  'louisbourg',
#  'codrington',
#  'marathopolis',
#  'havelock',
#  'vila',
#  'latung',
#  'ust-ishim',
#  'neryungri',
#  'ucluelet',
#  'monrovia',
#  'matatlan',
#  'fredericksburg',
#  'penzance',
#  'mweka',
#  'loa janan',
#  'port hedland',
#  'kieta',
#  'quatre cocos',
#  'novyy urengoy',
#  'wukari',
#  'sao joao da barra',
#  'kuntaur',
#  'faanui',
#  'kokopo',
#  'rabo de peixe',
#  'south lake tahoe',
#  'grindavik',
#  'dingle',
#  'betioky',
#  'mogochin',
#  'non thai',
#  'rocha',
#  'warqla',
#  'lagdo',
#  'lakkion',
#  'tabou',
#  'comodoro rivadavia',
#  'kidal',
#  'duz',
#  'puerto escondido',
#  'labutta',
#  'padang',
#  'shumskiy',
#  'diapaga',
#  'vao',
#  'verkhnyaya inta',
#  'northam',
#  'guaraniacu',
#  'batagay',
#  'yuli',
#  'aquiraz',
#  'valentin gomez farias',
#  'san lorenzo',
#  'walvis bay',
#  'nabire',
#  'skibbereen',
#  'lensk',
#  'lasa',
#  'rovaniemi',
#  'xingcheng',
#  'pangkalanbuun',
#  'saint-georges',
#  'poya',
#  'galveston',
#  'stropkov',
#  'cap malheureux',
#  'lazaro cardenas',
#  'opuwo',
#  'moulmeingyun',
#  'aden',
#  'semnan',
#  'port said',
#  'pathein',
#  'solwezi',
#  'upata',
#  'wanning',
#  'tateyama',
#  'jingdezhen',
#  'calamar',
#  'usvyaty',
#  'port hueneme',
#  'kishapu',
#  'jarocin',
#  'dumai',
#  'nalut',
#  'inhambane',
#  'venice',
#  'kutum']

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"{city}")
   
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})
                         
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# kununurra
# galle
# pizarro
# nago
# honiara
# terra rica
# akureyri
# adelaide
# bilibino
# san ignacio
# balkanabat
# waitati
# yverdon
# City not found. Skipping...
# mao
# manubul
# mount gambier
# isangel
# chardara
# sijunjung
# numan
# conde
# ladario
# biak
# plettenberg bay
# boma
# batemans bay
# maridi
# praia da vitoria
# vandra
# rabaul
# kilindoni
# fairbanks
# baracoa
# payyannur
# atagay
# haines junction
# raudeberg
# taltal
# hunza
# City not found. Skipping...
# shetpe
# bandarbeyla
# kaseda
# kholm-zhirkovskiy
# aswan
# nishihara
# sept-iles
# shimoda
# louisbourg
# City not found. Skipping...
# codrington
# marathopolis
# City not found. Skipping...
# havelock
# vila
# latung
# ust-ishim
# neryungri
# ucluelet
# monrovia
# matatlan
# City not found. Skipping...
# fredericksburg
# penzance
# mweka
# loa janan
# port hedland
# kieta
# quatre cocos
# novyy urengoy
# wukari
# sao joao da barra
# kuntaur
# faanui
# kokopo
# rabo de peixe
# south lake tahoe
# grindavik
# dingle
# betioky
# mogochin
# City not found. Skipping...
# non thai
# rocha
# warqla
# City not found. Skipping...
# lagdo
# lakkion
# tabou
# comodoro rivadavia
# kidal
# duz
# City not found. Skipping...
# puerto escondido
# labutta
# City not found. Skipping...
# padang
# shumskiy
# diapaga
# vao
# verkhnyaya inta
# northam
# guaraniacu
# batagay
# yuli
# aquiraz
# valentin gomez farias
# san lorenzo
# walvis bay
# nabire
# skibbereen
# lensk
# lasa
# rovaniemi
# xingcheng
# pangkalanbuun
# saint-georges
# poya
# galveston
# stropkov
# cap malheureux
# lazaro cardenas
# opuwo
# moulmeingyun
# City not found. Skipping...
# aden
# semnan
# port said
# pathein
# solwezi
# upata
# wanning
# tateyama
# jingdezhen
# calamar
# usvyaty
# port hueneme
# kishapu
# jarocin
# dumai
# nalut
# inhambane
# venice
# kutum

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
len(city_data_df)
# Out:
# 703

# %%
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     51.04        83          89
# 1          Hilo      US  19.7297 -155.0900     78.24        73           1
# 2        Albany      US  42.6001  -73.9662     61.16        78          93
# 3     Carnarvon      AU -24.8667  113.6333     68.07        68          90
# 4    Karlskrona      SE  56.1616   15.5866     50.45        95          98
# ..          ...     ...      ...       ...       ...       ...         ...
# 698       Dumai      ID   1.6833  101.4500     74.10        98          97
# 699       Nalut      LY  30.3333   10.8500     72.95        27           4
# 700   Inhambane      MZ -23.8650   35.3833     69.78        88           0
# 701      Venice      US  27.0998  -82.4543     78.84        66           1
# 702       Kutum      SD  14.2000   24.6667     83.12        21          87
#
#      Wind Speed Current Description
# 0         16.33     overcast clouds
# 1          5.75           clear sky
# 2         11.83     overcast clouds
# 3         20.71     overcast clouds
# 4          9.37     overcast clouds
# ..          ...                 ...
# 698        2.64     overcast clouds
# 699        7.00           clear sky
# 700        0.00           clear sky
# 701        5.99           clear sky
# 702        6.40     overcast clouds
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
